# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# simplest sequential layer

model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# c:\ProgramData\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile the model

model.compile(optimizer="sgd", loss="mean_squared_error")

# %%
# make numpy arrays for data

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
# training of neural network

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 30.6760
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 24.1433
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 19.0036
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 14.9597
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 11.7779
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.2745
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.3048
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.7550
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.5355
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.5759
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.8207
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.2265
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.7588
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3907
# Epoch 15/500
# ...

# %%
# predict model

print(model.predict(np.array([[10]])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# [[31.003542]]

# %%
print(model.predict(np.array([[19]])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[58.008167]]

# %% [markdown]
# # Another dataset with same compiler

# %%
# simplest sequential layer

model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# compile the model

model.compile(optimizer="sgd", loss="mean_squared_error")

# make numpy arrays for data

xs = (
    np.array([10, 20, 30, 40], dtype=float) / 10
)  # this 10 is just to scale the data to 0-1 range
ys = np.array([15, 25, 35, 45], dtype=float) / 10  # y = x + 5

# training of neural network

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 51.8649
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 35.9925
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 24.9790
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 17.3369
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 12.0342
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.3548
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.8017
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.0301
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.8008
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9478
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.3559
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9451
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6601
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4623
# Epoch 15/500
# ...

# %%
print(model.predict(np.array([[100 / 10]])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [[10.337854]]
