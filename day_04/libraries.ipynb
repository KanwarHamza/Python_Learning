# %% [markdown]
# 1.pandas\
# #pandas stands for panel data and is used for data manipulation and analysis\
#
# 2.numpy\
# #numpy stands for numerical python and is used for numerical operations\
#
# 3.matplotlib\
# #matplotlib is a plotting library for python\
#
# 4.seaborn\
# #seaborn is a visualization library based on matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics\
#
# 5.plotly\
# #plotly is a high-level, declarative charting library that allows users to create interactive, web-based visualizations in a simple and intuitive way\
#
# 6.scipy\
# #scipy is a library for scientific and engineering applications that provides functions for scientific and engineering applications such as signal processing, linear algebra, and optimization\
#
# 7.scikit-learn\
# #scikit-learn is a machine learning library for python that provides a wide range of algorithms for classification, regression, clustering, and other tasks\
#
# 8.streamlit\
# #streamlit is a library for building web applications that allows users to create interactive, web-based visualizations and applications in a simple and intuitive way\

# %% [markdown]
# #pip install with the name of the package to install packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

# %% [markdown]
# you have to install libraries once but have to import libraries everytime you use them. This is a good practice to avoid polluting the namespace and to make the code more readable.

# %% [markdown]
# # plotting

# %%
# plotting
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17764\4069733661.py:8: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
import nbformat as nbf
import plotly.express as px

df=px.data.gapminder()

fig=px.bar(df, x="continent", y="pop", color="continent",
           animation_frame="year", animation_group="country", range_y=[0,4000000000])
fig.show()
